# %%
# %matplotlib inline
from ggplot import * 
import pandas as pd

# %%
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
meat.head()
# Out:
#         date   beef   veal    pork  lamb_and_mutton  broilers  other_chicken  \
# 0 1944-01-01  751.0   85.0  1280.0             89.0       NaN            NaN
# 1 1944-02-01  713.0   77.0  1169.0             72.0       NaN            NaN
# 2 1944-03-01  741.0   90.0  1128.0             75.0       NaN            NaN
# 3 1944-04-01  650.0   89.0   978.0             66.0       NaN            NaN
# 4 1944-05-01  681.0  106.0  1029.0             78.0       NaN            NaN
#
#    turkey
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
mtcars.head()
# Out:
#                 name   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
p = ggplot(aes(x='date',y='pork'), data = meat)
p + geom_point(color='red') + geom_line(color='green') + stat_smooth(color='blue', method = 'loess') 
#geom_line() + geom_point()
# Out:
# /usr/local/lib/python3.5/site-packages/ggplot/stats/stat_smooth.py:77: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   smoothed_data = smoothed_data.sort('x')
# <ggplot: (8784417812814)>

# %%
p = ggplot(aes(x='pork'), data = meat)
p + geom_histogram() + xlab("distribution pork prices") + ylab("price of pork") +\
ggtitle("Test\ntitle")
# Out:
# <ggplot: (8784417772250)>

# %%
stat_smooth?

# %%
ggplot(aes(x='carat', y='price', color='clarity'), data = diamonds) + geom_point() + xlim(0,4)
# Out:
# <ggplot: (8784517197502)>

# %%
ggplot(aes(x='carat'), data = diamonds) + geom_histogram(bins=30) + xlim(0,3)
# Out:
# <ggplot: (8784417717687)>

# %%
ggplot(aes(x='mpg'), data=mtcars) + geom_histogram() + xlab("Number of cars with given mpg")
# Out:
# <ggplot: (8784417632867)>

# %%
ggplot(diamonds, aes(x='price')) + geom_histogram(bins=30)
# Out:
# <ggplot: (-9223363252437561863)>

# %%
ggplot(mtcars, aes(x='factor(cyl)', fill = 'factor(gear)')) + geom_bar()
# Out:
# /usr/local/lib/python3.5/site-packages/ggplot/ggplot.py:602: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   fill_levels = self.data[[fillcol_raw, fillcol]].sort(fillcol_raw)[fillcol].unique()
# <ggplot: (8784417591360)>

# %%
ggplot(aes(x='carat', y='price', color = 'cut'), data = diamonds) + geom_point() +\
stat_smooth() + facet_wrap('clarity')
# Out:
# /usr/local/lib/python3.5/site-packages/ggplot/stats/stat_smooth.py:77: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   smoothed_data = smoothed_data.sort('x')
# <ggplot: (8784416995697)>

# %%
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %%
ggplot(aes(x='class', y='hwy'), data=mpg) + geom_boxplot() + facet_wrap('cyl')
# Out:
# <ggplot: (8784400858979)>

# %%
meat.head()
# Out:
#         date   beef   veal    pork  lamb_and_mutton  broilers  other_chicken  \
# 0 1944-01-01  751.0   85.0  1280.0             89.0       NaN            NaN
# 1 1944-02-01  713.0   77.0  1169.0             72.0       NaN            NaN
# 2 1944-03-01  741.0   90.0  1128.0             75.0       NaN            NaN
# 3 1944-04-01  650.0   89.0   978.0             66.0       NaN            NaN
# 4 1944-05-01  681.0  106.0  1029.0             78.0       NaN            NaN
#
#    turkey
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
meat = pd.melt(meat, id_vars="date")
meat.head()
# Out:
#         date  variable value
# 0 1944-01-01  variable  beef
# 1 1944-02-01  variable  beef
# 2 1944-03-01  variable  beef
# 3 1944-04-01  variable  beef
# 4 1944-05-01  variable  beef
